# %%
from ssl_subs_generation.requirements import *

# %%
metadata_path = os.path.join(DATA_DIR, "metadata_normal.tsv")

# %%
df = pd.read_csv(metadata_path, sep="\t")

# %%
df.head()

# %%
df = pd.read_csv(metadata_path, sep='\t')

df['path_column_name'] = df['path_column_name'].str.replace('\\', '/', regex=False)
df.to_csv(os.path.join(DATA_DIR, 'metadata_clean.tsv'), sep='\t', index=False)
