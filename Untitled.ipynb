# %%
import pandas as pd

# %%
df = pd.read_csv("data/metadata.tsv", sep="\t")
df.head()
# Out:
#                             path            transcript
# 0  data\audio\4a\4aa1fdca33.flac      ००७ मिलको दूरीमा
# 1  data\audio\86\86e521554a.flac      ००७ मिलको दूरीमा
# 2  data\audio\c9\c96b2b1afb.flac      ००७ मिलको दूरीमा
# 3  data\audio\2f\2f7ab41953.flac  ०११ देखि काङ्ग्रेसको
# 4  data\audio\c2\c290e5124b.flac      ०१ सौर द्रव्यमान

# %%
path = df['path'].tolist()

# %%
path
# Out:
# ['data\\audio\\4a\\4aa1fdca33.flac',
#  'data\\audio\\86\\86e521554a.flac',
#  'data\\audio\\c9\\c96b2b1afb.flac',
#  'data\\audio\\2f\\2f7ab41953.flac',
#  'data\\audio\\c2\\c290e5124b.flac',
#  'data\\audio\\1d\\1d7f225bd0.flac',
#  'data\\audio\\5e\\5e766d189e.flac',
#  'data\\audio\\81\\8190842174.flac',
#  'data\\audio\\b6\\b6c37578d2.flac',
#  'data\\audio\\c4\\c40938bd06.flac',
#  'data\\audio\\c8\\c89e1079c6.flac',
#  'data\\audio\\2b\\2bedce5635.flac',
#  'data\\audio\\e4\\e4ed3e951c.flac',
#  'data\\audio\\0b\\0ba8e6bacd.flac',
#  'data\\audio\\de\\de4dc39a7a.flac',
#  'data\\audio\\3e\\3ed2cee22b.flac',
#  'data\\audio\\96\\96cf842c07.flac',
#  'data\\audio\\a7\\a7f5ba44bb.flac',
#  'data\\audio\\6c\\6c3b5fab5f.flac',
#  'data\\audio\\c9\\c977a4d3eb.flac',
#  'data\\audio\\d4\\d4ff76ee65.flac',
#  'data\\audio\\6d\\6d49b03fdc.flac',
#  'data\\audio\\74\\74c4e5c052.flac',
#  'data\\audio\\76\\76eebeef6c.flac',
#  'data\\audio\\f9\\f911dd9e32.flac',
# ...
